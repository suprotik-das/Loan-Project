# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("loan.csv")
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.describe()   # 1 - Display descriptive statistics on the dataset
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
descriptive_stats = df.describe()
print(descriptive_stats)
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df[df.isna().any(axis=1)]   # 2 - to display missing or null values
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 16   LP001034    Male      No          1  Not Graduate            No
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 592  LP002933     NaN      No         3+      Graduate           Yes
# 597  LP002943    Male      No        NaN      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 601  LP002950    Male     Yes          0  Not Graduate           NaN
# 605  LP002960    Male     Yes          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x=df["ApplicantIncome"].to_numpy()    # 3 - 
y=df["LoanAmount"].to_numpy()
df1=plt.scatter(x,y)
plt.title("relation visualization with scatter plot")
plt.xlabel("ApplicantIncome")
plt.ylabel("LoanAmount")
# Out:
# Text(0, 0.5, 'LoanAmount')

# %%
df.loc[:,'ApplicantIncome'].corr(df.loc[:,'LoanAmount'],method='pearson',min_periods=1)

# identify the location(ApplicantIncome) & correation with LoanAmount
# Out:
# 0.5709090389885669

# %%
boxplot = df.boxplot(column=['ApplicantIncome','LoanAmount'])  # 4 - for box plotting

# %%
df.Dependents.unique()   # 5 - display unique values
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
data_crosstab = pd.crosstab(df['Loan_Status'],df['ApplicantIncome'])
print(data_crosstab)

# 6 - in case of contingency table, need to use 'crosstab'
# Out:
# ApplicantIncome  150    210    416    645    674    1000   1025   1299   \
# Loan_Status
# N                    1      0      1      0      0      1      0      0
# Y                    0      1      0      1      1      0      2      1
#
# ApplicantIncome  1378   1442   ...  20667  20833  23803  33846  37719  39147  \
# Loan_Status                    ...
# N                    1      1  ...      1      0      0      1      0      0
# Y                    0      0  ...      0      1      1      0      1      1
#
# ApplicantIncome  39999  51763  63337  81000
# Loan_Status
# N                    0      0      0      1
# Y                    1      1      1      0
#
# [2 rows x 505 columns]

# %%
df_row = df.iloc[1:11,[8]]   # 7
df_row.describe()
# Out:
#        LoanAmount
# count   10.000000
# mean   156.200000
# std     88.969158
# min     66.000000
# 25%    101.250000
# 50%    134.500000
# 75%    165.500000
# max    349.000000
